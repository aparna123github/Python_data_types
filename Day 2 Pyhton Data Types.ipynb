# %%
a=1
b= 'string'
c= 9.10
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
a=1
c=2
a+c
# Out:
# 3

# %%
a=5
X=7
a//X
# Out:
# 0

# %%
a=4
b=5
a==b
# Out:
# False

# %%
a=10
b=30
a>=b
# Out:
# False

# %%
a=10
b=20
print(a/b)
print(a//b)
print(a*b)
print(a+b
# Out:
#   Cell In[6], line 6
#     print(a+b
#              ^
# _IncompleteInputError: incomplete input

# %%
x="gekks"
y="computer"
print(x)
del x 
print(x)

# %%
swapping two variables

# %%
a,b =5,10
a,b =b,a
print(a,b)

# %%
counting characters in a string

# %%
word = "palak"
length= len(word)
print( "length of the word:",length)

# %%
a="palak"
length =len(a)
print("length of a:",length)

# %%
b= "hello world"
length= len(b)
print(length)

# %% [markdown]
# # INTEGER

# %%
age= "21"
print ("age=",int (age))
# Out:
# age= 21

# %%
print(int(12.1))
print(int('12'))
print(int(30)) 
print(int(True))     # to complex and to strings it is not possile
# Out:
# 12
# 12
# 30
# 1

# %%
print(str("12"))
print(float(14))
print((True))
print(complex(12))   #every data type is posible to int
# Out:
# 12
# 14.0
# True
# (12+0j)

# %% [markdown]
# # FLOAT

# %%
a= 3.4
b= -532.422     #negative float
c= 123.4e3      # scinetific notation where e=10
d= 2.0
e= 839.2e-3

print (type(a))
print (type(b))
print (type(c))
print (type(d))
print (type(e))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
print(float(True))
print(float(3222))

print(float(True))
print(float())       #no argument
                     #complex is also not allowed  
                     #string to float is not allowed
# Out:
# 1.0
# 3222.0
# 1.0
# 0.0

# %%
print(str(2.32)) 
print(int(2.32)) 
print(bool(2.32)) 
print(complex(2.32))   #every data type to bool is allowed
# Out:
# 2.32
# 2
# True
# (2.32+0j)

# %% [markdown]
# # COMPLEX

# %%
c1= complex(3,4)
print(c1)
c2= complex(3.4,2.292)
print (c2)
# Out:
# (3+4j)
# (3.4+2.292j)

# %%
c1
# Out:
# (3+4j)

# %%
c= complex() #with one argument
c
c3= complex(44)  #with one argument
c3
                 # string argument is not allowed
# Out:
# (44+0j)

# %%
print(complex(2.4))
print(complex(44))
print(complex(-2))
print(complex(True))   # ecery data type to complex is possible
# Out:
# (2.4+0j)
# (44+0j)
# (-2+0j)
# (1+0j)

# %%
print(str(1+3j))
print(bool(1+3j))
print(int(4+3j))     #int is not allowed
print(float(1+3j))                  #float is not allowed
# Out:
# (1+3j)
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 3
#       1 print(str(1+3j))
#       2 print(bool(1+3j))
# ----> 3 print(int(4+3j))     #int is not allowed
#       4 print(float(1+3j))                  #float is not allowed
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# # STRINGS

# %%
s1 ='gfg'
s2= "GFG"
s1 
s2

# %%
s3 = """i am 
leaning python
at home"""
print(s3)

# %%
s3    #both are different

# %% [markdown]
# # Acessing charcter in strings

# %%
s1

# %%
a="helloworld"

# %%
print(a[0]) #first character
print(a[4]) #fifth character
# Out:
# h
# o

# %%
print(a[2:4])
# Out:
# ll

# %%
print(a[1:4])                 #STRING SLICING
print(a[3:6])
print(a[0:7])
print(a[2:3])
# Out:
# ell
# low
# hellowo
# l

# %%
print(a[-5:-3])
# Out:
# wo

# %%
print(a[-3:-4}])  #alwasy lfet to right indexing
# Out:
#   Cell In[32], line 1
#     print(a[-3:-4}])  #alwasy lfet to right indexing
#                  ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %%
p = "hello geeks"
print(p.replace( "hello", "bye"))    #updating a string
print(p.upper())
print(p.lower())
print(len(p))
# Out:
# bye geeks
# HELLO GEEKS
# hello geeks
# 11
# <built-in method strip of str object at 0x0000023C37C72BF0>

# %%
s1= "hello"
s2= "world"
print( s1 +" "+ s2)   # concateing strings
# Out:
# hello world
