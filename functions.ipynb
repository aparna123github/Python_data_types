# %% [markdown]
# ## import math function

# %%
x = sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 x = sqrt(25)
#
# NameError: name 'sqrt' is not defined

# %%
import math  #math is a module
math.sqrt(25)

# %%
x1 = math.sqrt(15)
x1

# %%
#how many function does math have will find wth
help(math) or
#math.tab

# %%
#correct format to write code
import math
from math import sqrt
import math as m

# %%
print(math.floor(3.87))  #FLOOR- minimum or least value

# %%
print(math.ceil(3.87))  #CEIL - max or atmost value

# %%
round(3.87)

# %%
round(3.37)

# %%
3 * 2

# %%
3 **2

# %%
print(math.pow(3,2)) # 3 to the power 2

# %%
pi = 40.2  #in python the pi value is not fixed,as we have a concept of only varibale
pi

# %%
math.e  #epsilon value

# %%
import math as m   #short form of maths,so firstly we have to define m
m.pow(2,3)

# %%
import keyword  #total 35 keywords
keyword.kwlist

# %%
from math import sqrt,pow,ceil, floor #math have many function, so we can use them as these
print(pow(2,3))
print(m.sqrt(10))
print(m.floor(3.5))
print(m.ceil(22.1))

# %%
from math import *  # * STAR refers to all
print(pow(2,3))
print(m.sqrt(10))
print(m.floor(3.5))
print(m.ceil(22.1))

# %% [markdown]
# ## user input in python

# %%
x = input()
x
# Out:
#  2
# '2'

# %% [raw]
# int()  always a string
# use int()/float() for numbers

# %%
type (x)  #string type
# Out:
# str

# %%
x = input ()
y =input()

z = x+y       #Read a string from standard input
print(z)
# Out:
#  2
#  3
# 23

# %%
x = int(input ())
y = int(input())

z = x+y       #to add the no. we have to convert it into int,as these are all in strings
print(z)
# Out:
#  2
#  3
# 5

# %%
x1 = int(input('enter the first number'))  #user input with the conversion of int*
y1 = int(input('enter the second number'))
z1 = x1 + y1
print(z1)
# Out:
# enter the first number 11
# enter the second number 11
# 22

# %%
#input with names
name = input("Enter your name: ")
print("Hello,", name)
# Out:
# Enter your name:  palak
# Hello, palak

# %%
#input with numbers
age = int(input("Enter your age: "))
print("Next year you will be", age + 1)
# Out:
# Enter your age:  21
# Next year you will be 22

# %%
#ADD TWO NUMBERS
def add(a, b):
    return a + b

x = int(input("Enter first number: "))   #ALWAYS REMEMBER HERE TO CCONVERT THE NO. IN INT
y = int(input("Enter second number: "))

print("Sum:", add(x, y))
# Out:
# Enter first number:  2
# Enter second number:  3
# Sum: 5

# %%
#FACTORIAL OF A NUMBER
from math import factorial

n = int(input("Enter number: "))
print(factorial(n))
# Out:
# Enter number:  5
# 120

# %%
x1 = input ('username:')
y1 = input ('password:')
z1 = x1 + y1
print(z1)
# Out:
# username: user
# password: 1122
# user1122

# %%
st = input ('enter a string')
print(st)
#print(type(ch))
# Out:
# enter a string palak
# palak

# %%
print(st[0])
# Out:
# p

# %%
print(st[0:3])
# Out:
# pal

# %%
st  = input ('enter a string')[1]  #example of adhar card,last digits will be shown
print(st)                          #input function,string, with index
# Out:
# enter a string hello
# e

# %%
st  = input ('enter a string')[5:12]  #example of adhar card,last digits will be shown
print(st)
# Out:
# enter a string 32113311189
# 311189

# %%
st  = input ('enter a string')   #here the evaluation didn't happened
print(st)
# Out:
# enter a string 2 + 3 *4
# 2 + 3 *4

# %%
st = eval( input ('enter a string'))  #therfore ww will pass EVAL*
print(st)
# Out:
# enter a string 2 + 3 *4
# 14

# %% [markdown]
# ## what is the output

# %%
x = int(input())
print(type(x))
#int
# Out:
#  10
# <class 'int'>

# %%
x = input()
print(type(x))
#str
# Out:
#  10
# <class 'str'>

# %%
x = input()
print(x + "10")  #as to add the no. we should convert it into int
#510
# Out:
#  5
# 510

# %%
from math import sqrt
print(type(sqrt))
#function
# Out:
# <class 'builtin_function_or_method'>

# %%
import math
print(type(math))
#module
# Out:
# <class 'module'>

# %%
def test():
    print("Hello")

x = test()
print(type(x))     #none,bcoz when it will return to the function the only it will be defined as string
#str
# Out:
# Hello
# <class 'NoneType'>

# %%
def test():
    return 10

x = test()
print(type(x))
#int            #ince it is defined now
# Out:
# <class 'int'>

# %%
from math import factorial
print(type(factorial(5)))
#function                   #int bcoz the factorial returns a int value
# Out:
# <class 'int'>

# %%
x = input()
print(type(x + "5"))
#str                 #since it's not defined here as well
# Out:
#  10
# <class 'str'>

# %%
x = int(input())
print(type(x / 2))
#int                #since the division would be in decimal value only
# Out:
#  4
# <class 'float'>

# %%
x = int(input())
print(type(x // 2))
#int               #now it's defined therfore it will be int
# Out:
#  4
# <class 'int'>

# %%
print(type(len("Python")))
#str                       #LENGTH OF PYTHO WILL RETURN A NUMBER
# Out:
# <class 'int'>

# %%
x = float(input())
y = int(x)
print(y)
#int
# Out:
#  4.9
# 4

# %%
def fun():
    return

print(fun())
#none,bcoz nothing is executed
# Out:
# None

# %%
def fun():
    print("A")
    return 10
    print("B")  #this line never executed

print(fun())
# 10
# Out:
# A
# 10

# %%
x = input()
print(x * 2)
# IT REPEATS THE STRING
# Out:
#  3
# 33
