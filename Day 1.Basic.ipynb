# %%
10*9
# Out:
# 90

# %%
10/5
# Out:
# 2.0

# %%
10//5
# Out:
# 2

# %%
10**5
# Out:
# 100000

# %%
p=1000
r=50
t=2
p*r*t
# Out:
# 100000

# %%
a=20
b=30
print(max(a,b))
# Out:
# 30

# %%
a=10
b=3
a+b
# Out:
# 13

# %%
y='welcome'
y[-3]
# Out:
# 'o'

# %%
y[3:]
# Out:
# 'come'

# %%
y[1:2:3]
# Out:
# 'e'

# %%
z= 'AparnaAgnihotri'
z[2:15:4]
# Out:
# 'aAhi'

# %%
print(l)
# Out:
# 1

# %%
l1=20

# %%
l
# Out:
# 1

# %%
l2=[30,40,50,30]

# %%
l2
# Out:
# str

# %%
print("hello",end=" ")
print("world.")        #print without a new line
# Out:
# hello world.

# %%
x= float(4)
y= int(8)
z= str(9)


print(x) 
print(y)
print(z)
# Out:
# 4.0
# 8
# 9

# %%
a_z=2
print( a_z) #a-z is wrong
# Out:
# 2

# %%
myVariableName = 'john'
print (myVariableName)      #CAMEL CASE
MyVariableName= 'palak'
print(MyVariableName)       #PASCAL CASE
MY_VARIABLE_NAME= 'RADHA'   #this could be in small letter as well
print(MY_VARIABLE_NAME)     #SNAKE CASE
# Out:
# john
# palak
# RADHA

# %%
a=4
b=5
print(a,b)
# Out:
# 4 5

# %%
a=6
A=8
print (a,A)    #CASE SENSTIVE
# Out:
# 6 8

# %%
x= "Python "
y= "is "
z= "awesome "
print(x+y+z)        #SPACE CHARACTER SH
# Out:
# Python is awesome
